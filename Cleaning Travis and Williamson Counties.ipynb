# %%
import pandas as pd
from pathlib import Path # importing files
from pyzillow.pyzillow import ZillowWrapper, GetDeepSearchResults # Zillow information

# %% [markdown]
# Austin counties: Hays, Travis, Williamson
# 78610, 78613, 78617, 78641, 78652, 78653, 78660, 78664, 78681, 78701, 78702, 78703, 78704, 78705, 78712, 78717, 78719, 78721, 78722, 78723, 78724, 78725, 78726, 78727, 78728, 78729, 78730, 78731, 78732, 78733, 78734, 78735, 78736, 78737, 78738, 78739, 78741, 78742, 78744, 78745, 78746, 78747, 78748, 78749, 78750, 78751, 78752, 78753, 78754, 78756, 78757, 78758, 78759.
#
#
#
# Cedar Park: Williamson 78613, Travis
# Leander: Williamson 78641, Travis
# Round Rock - Williamson 78664, Travis
# Georgetown  78626, 78628, 78633, 78665.

# %% [markdown]
# # Travis County

# %%
list_df = []
folder="Desktop/Zillow Data/Zip/Tra/"
for file in Path(folder).glob('*.csv'):
    df = pd.read_csv(file)
    list_df.append(df)
df_tra = pd.concat(list_df)

# %%
df_tra
# Out:
#       Property ID Geographic ID      Type  \
# 0          584968    0239720305      Real
# 1          240961    0237720101      Real
# 2          862578           NaN  Personal
# 3          525821    0227670202      Real
# 4          546304    0227670114      Real
# ...           ...           ...       ...
# 2621       281145   2.82301e+08      Real
# 2622       894543   2.86361e+08      Real
# 2623       482133   2.84301e+08      Real
# 2624       371365    2.9348e+08      Real
# 2625       482196    2.8433e+08      Real
#
#                          Property Address  \
# 0        12916 JAMES MADISON ST  TX 78653
# 1            13004 ARMSTRONG LN  TX 78653
# 2     11923 E U S HY 290  MANOR, TX 78653
# 3         11712 BRIARCREEK LOOP  TX 78653
# 4                 12104 LIMA DR  TX 78653
# ...                                   ...
# 2621       17018 JIGSAW PATHWAY  TX 78664
# 2622          2812 BRIDEKIRK DR  TX 78664
# 2623          1600 BALMORHEA LN  TX 78664
# 2624            1349 AMISTAD DR  TX 78664
# 2625       17603 FORT LEATON DR  TX 78664
#
#                                       Legal Description  \
# 0               LOT 35 BLK O PRESIDENTIAL MEADOWS SEC 2
# 1                     ABS 315 SUR 63 GATES G ACR 0.7702
# 2     PERSONAL PROPERTY COMMERCIAL 101 PARK AVENUE P...
# 3                    LOT 10 BLK B BRIARCREEK SUBD SEC 1
# 4                    LOT 26 BLK E BRIARCREEK SUBD SEC 2
# ...                                                 ...
# 2621              LOT 51 BLK M SPRINGBROOK CENTRE PHS A
# 2622                      LOT 10 BLK F GLEN ELLYN SEC 1
# 2623         LOT 13 BLK F CAMBRIDGE HEIGHTS PHS A SEC 2
# 2624                           LOT 26 HUNTINGTON TRAILS
# 2625       LOT 32 BLK B CAMBRIDGE HEIGHTS PHS A SEC 1-B
#
#                            Owner Name             Doing Business As  \
# 0      CALZADILLA JOSE LUIS RODRIGUEZ                           NaN
# 1                          1-40 GROUP                           NaN
# 2        101 PARK AVENUE PARTNERS INC  101 PARK AVENUE PARTNERS INC
# 3                    101 VENTURES LLC                           NaN
# 4                    101 VENTURES LLC                           NaN
# ...                               ...                           ...
# 2621              ZHU QIANG & YAN LIU                           NaN
# 2622            ZHU XINMIN & FAN WANG                           NaN
# 2623                      ZIPP SHERRY                           NaN
# 2624                     ZOCH RICHARD                           NaN
# 2625    ZURITA SERGIO & ADELA VALADEZ                           NaN
#
#      Appraised Value
# 0            177,203
# 1             83,878
# 2                609
# 3            139,879
# 4            160,422
# ...              ...
# 2621         239,350
# 2622         218,592
# 2623         242,546
# 2624         285,012
# 2625         192,861
#
# [399837 rows x 8 columns]

# %% [markdown]
# # Cleaning Travis County Dataset

# %% [markdown]
# First I need to remove buisnesses from my dataset

# %%
df_tra['company']=df_tra['Owner Name'].apply(lambda x: 1 if 'LLC' in x else 0) # dummy variable
df_tra = df_tra[df_tra.company==0] 
df_tra['company_1']=df_tra['Owner Name'].apply(lambda x: 1 if any(i.isdigit() for i in x) else 0) # dummy variable
df_tra = df_tra[df_tra.company_1==0]
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_tra
# Out:
#       Property ID Geographic ID      Type  \
# 0          584968    0239720305      Real
# 117        839808           NaN  Personal
# 119        238594    0235590605      Real
# 120        910140           NaN  Personal
# 121        730024    0241720110      Real
# ...           ...           ...       ...
# 2621       281145   2.82301e+08      Real
# 2622       894543   2.86361e+08      Real
# 2623       482133   2.84301e+08      Real
# 2624       371365    2.9348e+08      Real
# 2625       482196    2.8433e+08      Real
#
#                              Property Address  \
# 0            12916 JAMES MADISON ST  TX 78653
# 117          13419 E U S HY 290 11-C TX 78653
# 119                    EGGLESTON ST  TX 78653
# 120       15105 E U S HY 290  MANOR, TX 78653
# 121   13617 RICHARD NIXON ST  MANOR, TX 78653
# ...                                       ...
# 2621           17018 JIGSAW PATHWAY  TX 78664
# 2622              2812 BRIDEKIRK DR  TX 78664
# 2623              1600 BALMORHEA LN  TX 78664
# 2624                1349 AMISTAD DR  TX 78664
# 2625           17603 FORT LEATON DR  TX 78664
#
#                                       Legal Description  \
# 0               LOT 35 BLK O PRESIDENTIAL MEADOWS SEC 2
# 117   PERSONAL PROPERTY COMMERCIAL A PRIME MEDICAL H...
# 119                          LOT 5 BLK 46 MANOR TOWN OF
# 120            PERSONAL PROPERTY COMMERCIAL AAA STORAGE
# 121             LOT 56 BLK H PRESIDENTIAL MEADOWS SEC 4
# ...                                                 ...
# 2621              LOT 51 BLK M SPRINGBROOK CENTRE PHS A
# 2622                      LOT 10 BLK F GLEN ELLYN SEC 1
# 2623         LOT 13 BLK F CAMBRIDGE HEIGHTS PHS A SEC 2
# 2624                           LOT 26 HUNTINGTON TRAILS
# 2625       LOT 32 BLK B CAMBRIDGE HEIGHTS PHS A SEC 1-B
#
#                               Owner Name                Doing Business As  \
# 0         CALZADILLA JOSE LUIS RODRIGUEZ                              NaN
# 117      A PRIME MEDICAL HOME HEALTH INC  A PRIME MEDICAL HOME HEALTH INC
# 119   AAA FIRE & SAFETY EQUIPMENT CO INC                              NaN
# 120                          AAA STORAGE                      AAA STORAGE
# 121                AALBERS JOAN & GERALD                              NaN
# ...                                  ...                              ...
# 2621                 ZHU QIANG & YAN LIU                              NaN
# 2622               ZHU XINMIN & FAN WANG                              NaN
# 2623                         ZIPP SHERRY                              NaN
# 2624                        ZOCH RICHARD                              NaN
# 2625       ZURITA SERGIO & ADELA VALADEZ                              NaN
#
#      Appraised Value  company  company_1
# 0            177,203        0          0
# 117           18,283        0          0
# 119           35,000        0          0
# 120                0        0          0
# 121          203,999        0          0
# ...              ...      ...        ...
# 2621         239,350        0          0
# 2622         218,592        0          0
# 2623         242,546        0          0
# 2624         285,012        0          0
# 2625         192,861        0          0
#
# [364121 rows x 10 columns]

# %% [markdown]
# Now will delete all "personal" type of property

# %%
df_tra = df_tra[df_tra.Type=='Real'] 
del df_tra['company']
del df_tra['company_1']
del df_tra['Geographic ID']
del df_tra['Property ID']
del df_tra['Type']
del df_tra['Legal Description']
del df_tra['Owner Name']
del df_tra['Doing Business As']

# %%
list_zips = []
for row_index, row  in df_tra['Property Address'].iteritems():
    
    zipcode = row.split()[-1][:5]
    list_zips.append(zipcode)

# %%
df_tra['zipcodes'] = list_zips
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
list_addresses = []
for row_index, row  in df_tra['Property Address'].iteritems():

    address = ' '.join(row.split()[:-1])
    list_addresses.append(address)

# %%
df_tra['Address'] = list_addresses
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
del df_tra['Property Address']
df_tra = df_tra.reset_index()
df_tra = df_tra.drop_duplicates(subset='Address', keep='first')

# %%
df_tra.zipcodes.unique()
# Out:
# array(['78653', '78746', '78669', '78747', '78610', '78660', '78704',
#        '78749', '78652', '78641', '78748', '78745', '78752', '78734',
#        '78759', '78645', '78753', '78758', '78617', '78621', '78751',
#        '78750', '78757', '78613', '78742', '78735', '78727', '78726',
#        '78741', '78724', '78738', '78739', '78725', '78729', '78723',
#        '78722', '78728', '78736', '78730', '78731', '78737', '78719',
#        '78721', '78733', '78712', '78705', '78732', '78701', '78744',
#        '78702', '78703', '78756', '78754', '78681', '78664'], dtype=object)

# %%
df_tra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 312927 entries, 0 to 328643
# Data columns (total 4 columns):
# index              312927 non-null int64
# Appraised Value    312927 non-null object
# zipcodes           312927 non-null object
# Address            312927 non-null object
# dtypes: int64(1), object(3)
# memory usage: 11.9+ MB

# %%
df_tra['Address'] = df_tra['Address'].str.strip()

# %%
df_tra[df_tra['Address'] == '21339 BLAKE-MANOR RD TX']
# Out:
#    index Appraised Value zipcodes                  Address
# 4    123         210,457    78653  21339 BLAKE-MANOR RD TX

# %%
df_tra.to_csv('df_travis.csv')

# %% [markdown]
# year_built_3189_4190

# %%
home_type_3189_4190 = []
year_built_3189_4190 = []
home_size_3189_4190 = []
bathrooms_3189_4190 = []
bedrooms_3189_4190 = []
last_sold_date_3189_4190 = []
last_sold_price_3189_4190 = []
latitude_3189_4190 = []
longitude_3189_4190  = []
zestimate_amount_3189_4190 = []


'''num_floors
parking_type
heating_sources
heating_system
neighborhood
school_district'''
# Out:
# 'num_floors\nparking_type\nheating_sources\nheating_system\nneighborhood\nschool_district'

# %%
df_tra.head()
# Out:
#    index Appraised Value    Zip                          Address
# 0      0         177,203  78653        12916 JAMES MADISON ST TX
# 1    119          35,000  78653                  EGGLESTON ST TX
# 2    121         203,999  78653  13617 RICHARD NIXON ST MANOR TX
# 3    122         228,677  78653          18905 GREAT FALLS DR TX
# 4    123         210,457  78653          21339 BLAKE-MANOR RD TX

# %% [markdown]
# # Williamson County

# %%
list_df_wil = []
folder="Desktop/Zillow Data/Zip/Wil/"
for file in Path(folder).glob('*.csv'):
    df = pd.read_csv(file)
    list_df_wil.append(df)
    
df_wil = pd.concat(list_df_wil)
df_wil
# Out:
#       PROPERTY ID                 ACCOUNT                         OWNER NAME  \
# 0         R416487     R-20-6005-050G-0012                 HAMPTON, JANIS FAY
# 1         R097441     R-20-5900-0010-0044                 HAMPTON, JANIS FAY
# 2         R495001     R-20-6030-000C-0002          FORSTON, JEFFERY & SHELLY
# 3         R523855     R-20-5693-0201-0014                          LEE, PAUL
# 4         R522746     R-20-6030-5A0J-0014                YOUNG, JAMIE DWIGHT
# ...           ...                     ...                                ...
# 17075     P084272     P-16-9300-0600-0011  LINDELLS CHEVRON & AUTOMOTIVE INC
# 17076     P084695     P-16-9500-0950-0004     ROUND ROCK CHAMBER OF COMMERCE
# 17077     P459513  P-16-P194-7040-3866-89       BUDGET RENT-A-CAR SYSTEM INC
# 17078     P485013  P-16-P194-7040-4057-81      CHRISTIAN BROTHERS AUTOMOTIVE
# 17079     P472680  P-16-P194-7040-3968-16      CHURCH OF JESUS CHRIST OF LDS
#
#                                            SITUS ADDRESS 2019 ASSESSED VALUE
# 0                  309 BASTIAN LN, GEORGETOWN, TX  78626            $214,278
# 1              50107 FLINTROCK DR, GEORGETOWN, TX  78626            $188,217
# 2                123 VALLECITO DR, GEORGETOWN, TX  78626            $258,761
# 3               1129 DAYLILY LOOP, GEORGETOWN, TX  78626            $366,738
# 4          301 GRAND JUNCTION TRL, GEORGETOWN, TX  78626            $270,695
# ...                                                  ...                 ...
# 17075                2415 N IH 35, ROUND ROCK, TX  78664             $74,385
# 17076               212 E MAIN ST, ROUND ROCK, TX  78664                  $0
# 17077   661 LOUIS HENNA BLVD #360, ROUND ROCK, TX  78664          $1,136,114
# 17078        413 LOUIS HENNA BLVD, ROUND ROCK, TX  78664            $125,794
# 17079  3920 GATTIS SCHOOL RD #104, ROUND ROCK, TX  78664             $25,934
#
# [121489 rows x 5 columns]

# %%
del df_wil['ACCOUNT']
del df_wil['PROPERTY ID']
del df_wil['OWNER NAME']

# %%
list_zips_wil = []
for row_index, row  in df_wil['SITUS ADDRESS'].iteritems():
    
    zipcode = row.split()[-1][:5]
    list_zips_wil.append(zipcode)

# %%
df_wil['zipcodes'] = list_zips_wil

# %%
list_addresses_wil = []
for row_index, row  in df_wil['SITUS ADDRESS'].iteritems():

    address = ' '.join(row.split()[:-1])
    list_addresses_wil.append(address)

# %%
df_wil['Address'] = list_addresses_wil

# %%
del df_wil['SITUS ADDRESS']
df_wil = df_wil.reset_index()
df_wil = df_wil.drop_duplicates(subset='Address', keep='first')

# %%
df_wil
# Out:
#         index 2019 ASSESSED VALUE zipcodes  \
# 0           0            $214,278    78626
# 1           1            $188,217    78626
# 2           2            $258,761    78626
# 3           3            $366,738    78626
# 4           4            $270,695    78626
# ...       ...                 ...      ...
# 121479  17070             $17,770    78664
# 121481  17072              $3,400    78664
# 121484  17075             $74,385    78664
# 121485  17076                  $0    78664
# 121488  17079             $25,934    78664
#
#                                            Address
# 0                   309 BASTIAN LN, GEORGETOWN, TX
# 1               50107 FLINTROCK DR, GEORGETOWN, TX
# 2                 123 VALLECITO DR, GEORGETOWN, TX
# 3                1129 DAYLILY LOOP, GEORGETOWN, TX
# 4           301 GRAND JUNCTION TRL, GEORGETOWN, TX
# ...                                            ...
# 121479         1800 N MAYS ST #107, ROUND ROCK, TX
# 121481         1106 S MAYS ST #220, ROUND ROCK, TX
# 121484                2415 N IH 35, ROUND ROCK, TX
# 121485               212 E MAIN ST, ROUND ROCK, TX
# 121488  3920 GATTIS SCHOOL RD #104, ROUND ROCK, TX
#
# [112747 rows x 4 columns]

# %%
df_wil.to_csv('df_williamson.csv')
